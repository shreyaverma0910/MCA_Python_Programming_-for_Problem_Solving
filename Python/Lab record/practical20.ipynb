# %%
import pandas as pd

# Create the dataset using the given table
data = {
    "Student_ID": [101,102,103,104,105,106,107,108,109,110,111,112,113,114,115],
    "Name": ["Rahul Sharma","Priya Patel","Amit Kumar","Sneha Gupta","Vikram Singh",
             "Anjali Mehta","Rohan Verma","Pooja Reddy","Karan Joshi","Neha Iyer",
             "Arjun Nair","Divya Shah","Siddharth Rao","Kavya Desai","Aditya Pillai"],
    "Age": [20,19,21,20,22,19,21,20,19,22,20,21,19,20,22],
    "Marks": [85,78,92,67,None,73,95,82,70,91,None,84,89,79,93],
    "Attendance": [92.5,88,95,82.5,90,85.5,97,89,80,94.5,86.5,91,None,87.5,96]
}

# Load data into DataFrame
df = pd.DataFrame(data)

# 1. Display first five records
print("First five records:")
print(df.head())

# 2. Display shape of dataset
print("\nShape of the dataset (Rows, Columns):")
print(df.shape)

# 3. Display column names and data types
print("\nColumn names and data types:")
print(df.dtypes)

# 4. Check for missing values
print("\nMissing values in each column:")
print(df.isnull().sum())

# 5. Display statistical summary
print("\nStatistical summary:")
print(df.describe())
# Out:
# First five records:
#    Student_ID          Name  Age  Marks  Attendance
# 0         101  Rahul Sharma   20   85.0        92.5
# 1         102   Priya Patel   19   78.0        88.0
# 2         103    Amit Kumar   21   92.0        95.0
# 3         104   Sneha Gupta   20   67.0        82.5
# 4         105  Vikram Singh   22    NaN        90.0
#
# Shape of the dataset (Rows, Columns):
# (15, 5)
#
# Column names and data types:
# Student_ID      int64
# Name           object
# Age             int64
# Marks         float64
# Attendance    float64
# dtype: object
#
# Missing values in each column:
# Student_ID    0
# Name          0
# Age           0
# Marks         2
# Attendance    1
# dtype: int64
#
# Statistical summary:
#        Student_ID        Age      Marks  Attendance
# count   15.000000  15.000000  13.000000   14.000000
# mean   108.000000  20.333333  82.923077   89.642857
# std      4.472136   1.112697   9.114654    5.081749
# ...

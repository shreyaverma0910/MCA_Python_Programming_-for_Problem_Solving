# %%
# Probability of rolling a specific number on a dice
favorable = 1       
total = 6           

probability = favorable / total
print("Probability of rolling any specific number on a dice is:", probability)
# Out:
# Probability of rolling any specific number on a dice is: 0.16666666666666666

# %%
# Probability of flipping heads or tails
favorable = 1       
total = 2           

probability = favorable / total
print("Probability of getting heads or tails is:", probability)
# Out:
# Probability of getting heads or tails is: 0.5

# %%
from shapes.point import Point
from shapes.circle import Circle

# Create Point object
p = Point(4, 6)

# Create Circle object using Point
c = Circle(p, 3)

c.display()
# Out:
# Center: (4, 6)
# Radius: 3
# Area: 28.274333882308138
# Perimeter: 18.84955592153876
